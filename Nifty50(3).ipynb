# %%
import pandas as pd
Nifty_data=pd.read_csv("E:/summer/NIFTY50.csv",parse_dates=['Date'],index_col=['Date'])

# %%
#adding a new column for days 
Nifty_data['day']=Nifty_data.index.map(lambda x:x.day)

# %%
#adding a new column for months
Nifty_data['month']=Nifty_data.index.map(lambda x:x.month)

# %%
#adding a new column for years
Nifty_data['year']=Nifty_data.index.map(lambda x:x.year)

# %%
#Return calcultion using first_day and last_day of month
All_returns=list()
for i in range(2010,2019):
    for j in range(1,13):
        Open=Nifty_data.Open[(Nifty_data['year']==i) & (Nifty_data['month']==j)]
        if(Open.empty):
            continue;
        else :
            Open.index=range(1,len(Nifty_data[(Nifty_data['year']==i) & (Nifty_data['month']==j)])+1)
            returns=((Open[len(Open)]-Open[1])/Open[1])*100
            All_returns.append(returns)

# %%
#calculating moving average for each 5 days
Moving_avg=Nifty_data[['Open', 'High', 'Low', 'Close', 'Shares Traded', 'Turnover (Rs. Cr)']].rolling(window=5).mean()

# %%
#droping NaN values which comes due to LAG
Moving_avg=Moving_avg.dropna()

# %%
Nifty_data.head()
# Out:
#                Open     High      Low    Close  Shares Traded  \
# Date
# 2010-04-01  5249.20  5298.60  5249.20  5290.50      127773261
# 2010-04-05  5291.40  5377.55  5291.40  5368.40      132419861
# 2010-04-06  5369.65  5388.65  5351.70  5366.00      147051901
# 2010-04-07  5365.70  5399.65  5345.05  5374.65      166790249
# 2010-04-08  5376.30  5383.65  5290.25  5304.45      156785881
#
#             Turnover (Rs. Cr)  day  month  year
# Date
# 2010-04-01            5365.11    1      4  2010
# 2010-04-05            5762.97    5      4  2010
# 2010-04-06            5746.95    6      4  2010
# 2010-04-07            6530.95    7      4  2010
# 2010-04-08            5830.63    8      4  2010

# %%
import matplotlib.pyplot as plt

# %%
Moving_avg[['Open','High','Low','Close']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000280424EE438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002804259C0F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000280425D6048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000028042604FD0>],
#       dtype=object)

# %%
Moving_avg[['Shares Traded','Turnover (Rs. Cr)']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000280429429B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000280429F1550>],
#       dtype=object)

# %%
win_size=[7,30,90,365]

# %%
#plot graphs for Open column and rolling windows
for i in win_size:
    r1=Moving_avg[['Open']].rolling(window=i)
    plt.plot(Nifty_data[['Open']],label='Open')
    plt.plot(r1.mean()['Open'],label="rolling window="+str(i))
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()

# %%
#plot graphs for High column and rolling windows
for i in win_size:
    r1=Moving_avg[['High']].rolling(window=i)
    plt.plot(Nifty_data[['High']],label='High')
    plt.plot(r1.mean()['High'],label='rolling window='+str(i))
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()

# %%
# plot graphs for Low column and rolling windows
for i in win_size:
    r1=Moving_avg[['Low']].rolling(window=i)
    plt.plot(Nifty_data[['Low']],label='Low')
    plt.plot(r1.mean()['Low'],label='rolling window='+str(i))
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()

# %%
#plot values for Close column and rolling windows
for i in win_size:
    r1=Moving_avg[['Close']].rolling(window=i)
    plt.plot(Nifty_data[['Close']],label='Close')
    plt.plot(r1.mean()['Close'],label='rolling window='+str(i))
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()

# %%
#plot graph for Shares Traded column and rolling windows
for i in win_size:
    r2=Moving_avg['Shares Traded'].rolling(window=i)
    plt.plot(Nifty_data['Shares Traded'],color='grey')
    plt.plot(r2.mean(),label='rolling window='+str(i),color='red')
    plt.xlabel('Year')
    plt.ylabel('Sahres Traded 100 Millions')
    plt.legend()
    plt.show()

# %%
#plot graph for Turnover column and rolling windows
for i in win_size:
    r2=Moving_avg['Turnover (Rs. Cr)'].rolling(window=i)
    plt.plot(Nifty_data['Turnover (Rs. Cr)'],color='grey')
    plt.plot(r2.mean(),label='rolling window='+str(i),color='red')
    plt.xlabel('Year')
    plt.ylabel('Turnover (Rs. Cr)')
    plt.legend()
    plt.show()

# %%
import numpy as np

# %%
from statsmodels.tsa import stattools
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Calculating Autocorrelation function for each column for moving average

# %%
acf_Open=stattools.acf(Moving_avg['Open'])

# %%
plt.plot(acf_Open)
plt.show()

# %%
acf_Close=stattools.acf(Moving_avg['Close'])
plt.plot(acf_Close)
plt.show()

# %%
acf_High=stattools.acf(Moving_avg['High'])
plt.plot(acf_High)
plt.show()

# %%
acf_Low=stattools.acf(Moving_avg['Low'])
plt.plot(acf_Low)
plt.show()

# %%
acf_Shares=stattools.acf(Moving_avg['Shares Traded'])
plt.plot(acf_Shares)
plt.show()

# %%
acf_Turnover=stattools.acf(Moving_avg['Turnover (Rs. Cr)'])
plt.plot(acf_Turnover)
plt.show()

# %%
#Calculating Partial Autocorrelation function for each column for moving average

# %%
pacf_Open=stattools.pacf(Moving_avg['Open'])
plt.plot(pacf_Open)
plt.show()

# %%
pacf_Close=stattools.pacf(Nifty_data['Close'])
plt.plot(pacf_Close)
plt.show()

# %%
pacf_High=stattools.pacf(Moving_avg['High'])
plt.plot(pacf_High)
plt.show()

# %%
pacf_Low=stattools.pacf(Moving_avg['Low'])
plt.plot(pacf_Low)
plt.show()

# %%
pacf_Shares=stattools.pacf(Moving_avg['Shares Traded'])
plt.plot(pacf_Shares)
plt.show()

# %%
pacf_Turnover=stattools.pacf(Moving_avg['Turnover (Rs. Cr)'])
plt.plot(pacf_Turnover)
plt.show()

# %%
#pearson correlation measures the linear association between contineous varaiables
coff_corr_r1=Moving_avg.corr(method='pearson')

# %%
coff_corr_r1
# Out:
#                        Open      High       Low     Close  Shares Traded  \
# Open               1.000000  0.999954  0.999894  0.999880       0.388875
# High               0.999954  1.000000  0.999869  0.999927       0.391522
# Low                0.999894  0.999869  1.000000  0.999942       0.385225
# Close              0.999880  0.999927  0.999942  1.000000       0.388540
# Shares Traded      0.388875  0.391522  0.385225  0.388540       1.000000
# Turnover (Rs. Cr)  0.740121  0.742051  0.737150  0.739568       0.811145
#
#                    Turnover (Rs. Cr)
# Open                        0.740121
# High                        0.742051
# Low                         0.737150
# Close                       0.739568
# Shares Traded               0.811145
# Turnover (Rs. Cr)           1.000000

# %%
def Cod(Corr_coff):
    return (Corr_coff**2)*100;

# %%
#Cod is cofficient of determination
Cod(coff_corr_r1)
# Out:
#                          Open        High         Low       Close  \
# Open               100.000000   99.990778   99.978723   99.976095
# High                99.990778  100.000000   99.973891   99.985308
# Low                 99.978723   99.973891  100.000000   99.988316
# Close               99.976095   99.985308   99.988316  100.000000
# Shares Traded       15.122345   15.328977   14.839820   15.096346
# Turnover (Rs. Cr)   54.777919   55.064031   54.339043   54.696078
#
#                    Shares Traded  Turnover (Rs. Cr)
# Open                   15.122345          54.777919
# High                   15.328977          55.064031
# Low                    14.839820          54.339043
# Close                  15.096346          54.696078
# Shares Traded         100.000000          65.795683
# Turnover (Rs. Cr)      65.795683         100.000000

# %%
coff_corr_r2=Moving_avg.corr(method='kendall')

# %%
coff_corr_r2
# Out:
#                        Open      High       Low     Close  Shares Traded  \
# Open               1.000000  0.991487  0.987229  0.985324       0.246405
# High               0.991487  1.000000  0.986240  0.989009       0.249088
# Low                0.987229  0.986240  1.000000  0.990855       0.242898
# Close              0.985324  0.989009  0.990855  1.000000       0.246122
# Shares Traded      0.246405  0.249088  0.242898  0.246122       1.000000
# Turnover (Rs. Cr)  0.514356  0.517127  0.509693  0.513294       0.622111
#
#                    Turnover (Rs. Cr)
# Open                        0.514356
# High                        0.517127
# Low                         0.509693
# Close                       0.513294
# Shares Traded               0.622111
# Turnover (Rs. Cr)           1.000000

# %%
Cod(coff_corr_r2)
# Out:
#                          Open        High         Low       Close  \
# Open               100.000000   98.304732   97.462207   97.086397
# High                98.304732  100.000000   97.266934   97.813930
# Low                 97.462207   97.266934  100.000000   98.179295
# Close               97.086397   97.813930   98.179295  100.000000
# Shares Traded        6.071529    6.204486    5.899926    6.057594
# Turnover (Rs. Cr)   26.456249   26.742064   25.978710   26.347060
#
#                    Shares Traded  Turnover (Rs. Cr)
# Open                    6.071529          26.456249
# High                    6.204486          26.742064
# Low                     5.899926          25.978710
# Close                   6.057594          26.347060
# Shares Traded         100.000000          38.702191
# Turnover (Rs. Cr)      38.702191         100.000000

# %%
coff_corr_r3=Moving_avg.corr(method='spearman')

# %%
coff_corr_r3
# Out:
#                        Open      High       Low     Close  Shares Traded  \
# Open               1.000000  0.999878  0.999690  0.999672       0.361486
# High               0.999878  1.000000  0.999641  0.999797       0.365210
# Low                0.999690  0.999641  1.000000  0.999825       0.356212
# Close              0.999672  0.999797  0.999825  1.000000       0.360598
# Shares Traded      0.361486  0.365210  0.356212  0.360598       1.000000
# Turnover (Rs. Cr)  0.713312  0.716247  0.708134  0.712007       0.815384
#
#                    Turnover (Rs. Cr)
# Open                        0.713312
# High                        0.716247
# Low                         0.708134
# Close                       0.712007
# Shares Traded               0.815384
# Turnover (Rs. Cr)           1.000000

# %%
Cod(coff_corr_r3)
# Out:
#                          Open        High         Low       Close  \
# Open               100.000000   99.975514   99.938028   99.934387
# High                99.975514  100.000000   99.928188   99.959438
# Low                 99.938028   99.928188  100.000000   99.964964
# Close               99.934387   99.959438   99.964964  100.000000
# Shares Traded       13.067222   13.337843   12.688732   13.003069
# Turnover (Rs. Cr)   50.881357   51.300972   50.145434   50.695415
#
#                    Shares Traded  Turnover (Rs. Cr)
# Open                   13.067222          50.881357
# High                   13.337843          51.300972
# Low                    12.688732          50.145434
# Close                  13.003069          50.695415
# Shares Traded         100.000000          66.485074
# Turnover (Rs. Cr)      66.485074         100.000000

# %%
#calculating %jump , formula = ((p(t)/p(t-1))-1)*100
per_jump=((((Nifty_data/Nifty_data.shift(1))-1).abs())*100)
drops=['day','month','year']
per_jump=per_jump.drop(drops,1)
per_jump=per_jump.dropna()

# %%
per_jump=per_jump.dropna()

# %%
#plotting graphs for percentage jump
plt.plot(per_jump[['Open']],label='Open')
plt.plot(per_jump[['High']],label='High')
plt.plot(per_jump[['Low']],label='Low')
plt.plot(per_jump[['Close']],label='Close')
plt.xlabel('Year')
plt.ylabel('Rs.')
plt.legend()
plt.show()

# %%
    plt.plot(per_jump[['Shares Traded']],label='Sahres traded',color='orange')
    plt.plot(per_jump[['Turnover (Rs. Cr)']],label='Turnover (Rs. Cr)')
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()

# %%
def Dickeyfuller(test_series):
    result = stattools.adfuller(test_series)

    print('ADF Statistic: %f' % result[0])

    print('p-value: %f' % result[1])

    print('Critical Values:')

    for key, value in result[4].items():

        print('\t%s: %.3f' % (key, value))
    
    if(result[1]>0.05):
        print("     Time series is not stationary");
    else:
        print("     Time series is stationary")

# %%
for i in Nifty_data[['Open', 'High', 'Low', 'Close', 'Shares Traded', 'Turnover (Rs. Cr)']]:
    print("For Column "+i)
    Dickeyfuller(Nifty_data[i])
# Out:
# For Column Open
# ADF Statistic: -0.306389
# p-value: 0.924595
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is not stationary
# For Column High
# ADF Statistic: -0.277463
# p-value: 0.928636
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is not stationary
# For Column Low
# ADF Statistic: -0.349403
# p-value: 0.918210
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is not stationary
# For Column Close
# ADF Statistic: -0.371803
# p-value: 0.914701
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is not stationary
# For Column Shares Traded
# ADF Statistic: -5.220330
# p-value: 0.000008
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column Turnover (Rs. Cr)
# ADF Statistic: -3.437833
# p-value: 0.009735
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary

# %%
Diff=Nifty_data[['Open', 'High', 'Low', 'Close', 'Shares Traded', 'Turnover (Rs. Cr)']]-Nifty_data[['Open', 'High', 'Low', 'Close', 'Shares Traded', 'Turnover (Rs. Cr)']].shift(1)

Diff=Diff.dropna()

# %%
for i in Diff.columns:
    print("For Column "+i+":")
    Dickeyfuller(Diff[i])
# Out:
# For Column Open:
# ADF Statistic: -46.136639
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column High:
# ADF Statistic: -39.387213
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column Low:
# ADF Statistic: -43.364970
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column Close:
# ADF Statistic: -41.047846
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column Shares Traded:
# ADF Statistic: -16.256196
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary
# For Column Turnover (Rs. Cr):
# ADF Statistic: -16.859948
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#      Time series is stationary

# %%
#all the series are now stationary(There is no trend,seasonality and noise present).

# %%
for j in Diff.columns:
    plt.plot(Diff[j],color='grey')
    plt.plot(Diff.rolling(window=7)[j].mean(),color='red',label='Weekly mean')
    plt.xlabel('Year')
    plt.ylabel('Rs.')
    plt.legend()
    plt.show()
